# %% [markdown]
# # Deutsch–Jozsa Algorithm(DJA) with Rotation gate
#
# In realistic quantum systems, qubits can be affected by noise during the computation.
# To study this in the DJA, we introduce single-qubit rotation errors at different points of the algorithm.
#
# We consider rotation errors applied to a single qubit along one of the Pauli axes R(n)
#
# 1. Before the first H affects the initial superposition
# 2. After the first H  affects the superposed state before the oracle
# 3. After the oracle U_f affects the phase-amplified state
# 4. After the final H affects the final interference pattern before measurement

# %%
# %pip install -e ..
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Obtaining file:///home/f73aeabd-6de4-471d-92a9-1ba552ae6153/DeutschJozsaNoise
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from deutsch-jozsa-noise==0.0.1) (1.24.3)
# Requirement already satisfied: scipy in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from deutsch-jozsa-noise==0.0.1) (1.11.1)
# Requirement already satisfied: matplotlib in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from deutsch-jozsa-noise==0.0.1) (3.7.2)
# Requirement already satisfied: ipython in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from deutsch-jozsa-noise==0.0.1) (8.15.0)
# Requirement already satisfied: ipywidgets in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from deutsch-jozsa-noise==0.0.1) (8.0.4)
# Requirement already satisfied: notebook<7 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from deutsch-jozsa-noise==0.0.1) (6.5.4)
# Requirement already satisfied: qutip in /home/f73aeabd-6de4-471d-92a9-1ba552ae6153/.local/lib/python3.11/site-packages (from deutsch-jozsa-noise==0.0.1) (5.3.1)
# Requirement already satisfied: jinja2 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (6.3.2)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (23.2.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (21.3.0)
# Requirement already satisfied: traitlets>=4.2.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (5.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (7.4.9)
# Requirement already satisfied: ipython-genutils in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (0.2.0)
# Requirement already satisfied: nbformat in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (1.5.6)
# Requirement already satisfied: ipykernel in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (6.25.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (0.17.1)
# Requirement already satisfied: prometheus-client in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from notebook<7->deutsch-jozsa-noise==0.0.1) (0.5.5)
# Requirement already satisfied: backcall in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from ipython->deutsch-jozsa-noise==0.0.1) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from ipython->deutsch-jozsa-noise==0.0.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from ipython->deutsch-jozsa-noise==0.0.1) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from ipython->deutsch-jozsa-noise==0.0.1) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from ipython->deutsch-jozsa-noise==0.0.1) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from ipython->deutsch-jozsa-noise==0.0.1) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from ipython->deutsch-jozsa-noise==0.0.1) (2.15.1)
# Requirement already satisfied: stack-data in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from ipython->deutsch-jozsa-noise==0.0.1) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from ipython->deutsch-jozsa-noise==0.0.1) (4.8.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from ipywidgets->deutsch-jozsa-noise==0.0.1) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from ipywidgets->deutsch-jozsa-noise==0.0.1) (3.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from matplotlib->deutsch-jozsa-noise==0.0.1) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from matplotlib->deutsch-jozsa-noise==0.0.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from matplotlib->deutsch-jozsa-noise==0.0.1) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from matplotlib->deutsch-jozsa-noise==0.0.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from matplotlib->deutsch-jozsa-noise==0.0.1) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from matplotlib->deutsch-jozsa-noise==0.0.1) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from matplotlib->deutsch-jozsa-noise==0.0.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from matplotlib->deutsch-jozsa-noise==0.0.1) (2.8.2)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from ipykernel->notebook<7->deutsch-jozsa-noise==0.0.1) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from ipykernel->notebook<7->deutsch-jozsa-noise==0.0.1) (1.6.7)
# Requirement already satisfied: psutil in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from ipykernel->notebook<7->deutsch-jozsa-noise==0.0.1) (5.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from jedi>=0.16->ipython->deutsch-jozsa-noise==0.0.1) (0.8.3)
# Requirement already satisfied: entrypoints in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from jupyter-client>=5.3.4->notebook<7->deutsch-jozsa-noise==0.0.1) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from jupyter-core>=4.6.1->notebook<7->deutsch-jozsa-noise==0.0.1) (3.10.0)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook<7->deutsch-jozsa-noise==0.0.1) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook<7->deutsch-jozsa-noise==0.0.1) (0.2.2)
# Requirement already satisfied: lxml in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from nbconvert>=5->notebook<7->deutsch-jozsa-noise==0.0.1) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from nbconvert>=5->notebook<7->deutsch-jozsa-noise==0.0.1) (4.12.2)
# Requirement already satisfied: bleach in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from nbconvert>=5->notebook<7->deutsch-jozsa-noise==0.0.1) (4.1.0)
# Requirement already satisfied: defusedxml in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from nbconvert>=5->notebook<7->deutsch-jozsa-noise==0.0.1) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from nbconvert>=5->notebook<7->deutsch-jozsa-noise==0.0.1) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from nbconvert>=5->notebook<7->deutsch-jozsa-noise==0.0.1) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from nbconvert>=5->notebook<7->deutsch-jozsa-noise==0.0.1) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from nbconvert>=5->notebook<7->deutsch-jozsa-noise==0.0.1) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from nbconvert>=5->notebook<7->deutsch-jozsa-noise==0.0.1) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from nbconvert>=5->notebook<7->deutsch-jozsa-noise==0.0.1) (1.2.1)
# Requirement already satisfied: fastjsonschema in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from nbformat->notebook<7->deutsch-jozsa-noise==0.0.1) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from nbformat->notebook<7->deutsch-jozsa-noise==0.0.1) (4.17.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from pexpect>4.3->ipython->deutsch-jozsa-noise==0.0.1) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->deutsch-jozsa-noise==0.0.1) (0.2.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->deutsch-jozsa-noise==0.0.1) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from argon2-cffi->notebook<7->deutsch-jozsa-noise==0.0.1) (21.2.0)
# Requirement already satisfied: executing in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from stack-data->ipython->deutsch-jozsa-noise==0.0.1) (0.8.3)
# Requirement already satisfied: asttokens in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from stack-data->ipython->deutsch-jozsa-noise==0.0.1) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from stack-data->ipython->deutsch-jozsa-noise==0.0.1) (0.2.2)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->notebook<7->deutsch-jozsa-noise==0.0.1) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->notebook<7->deutsch-jozsa-noise==0.0.1) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook<7->deutsch-jozsa-noise==0.0.1) (3.5.0)
# Requirement already satisfied: websocket-client in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook<7->deutsch-jozsa-noise==0.0.1) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook<7->deutsch-jozsa-noise==0.0.1) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=5->notebook<7->deutsch-jozsa-noise==0.0.1) (2.4)
# Requirement already satisfied: webencodings in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from bleach->nbconvert>=5->notebook<7->deutsch-jozsa-noise==0.0.1) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook<7->deutsch-jozsa-noise==0.0.1) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook<7->deutsch-jozsa-noise==0.0.1) (1.2.0)
# Requirement already satisfied: pycparser in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook<7->deutsch-jozsa-noise==0.0.1) (2.21)
# Building wheels for collected packages: deutsch-jozsa-noise
#   Building editable for deutsch-jozsa-noise (pyproject.toml) ... done
#   Created wheel for deutsch-jozsa-noise: filename=deutsch_jozsa_noise-0.0.1-0.editable-py3-none-any.whl size=3620 sha256=f590e6eff966cc42799561b1a65e8d90c9872b82ed52e671bfcb459f4cfee826
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u7j1u750/wheels/1a/57/82/0a291a876b639691bb2bc68015e6c73757167f5c8b61f8ca77
# Successfully built deutsch-jozsa-noise
# Installing collected packages: deutsch-jozsa-noise
#   Attempting uninstall: deutsch-jozsa-noise
#     Found existing installation: deutsch-jozsa-noise 0.0.1
#     Uninstalling deutsch-jozsa-noise-0.0.1:
#       Successfully uninstalled deutsch-jozsa-noise-0.0.1
# Successfully installed deutsch-jozsa-noise-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.append('..')  # Goes up one folder
import quantum_algorithms as qa

import numpy as np
from collections import Counter

# %matplotlib inline

# %%
# Parameters
n = 1
theta = 0        
target_qubit = 0         
axis = (1, 0, 0)         


# Original Deutsch–Jozsa (no error)
const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_0)
bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(const, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(bal, n)

print("Original DJA")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()


# Error 1 (before Hadamards)
state_c1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c1, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b1, n)

print("DJA with E1 (before H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 2 (after first Hadamards)
state_c2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c2, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b2, n)

print("DJA with E2 (after first H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 3 (after oracle)
state_c3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c3, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b3, n)

print("DJA with E3 (after oracle)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 4 (after final Hadamards)
state_c4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c4, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b4, n)

print("DJA with E4 (after final H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
# Out:
# Original DJA
# P(0) c: 0.9999999999999996
# P(0) b: 1.0573994819069698e-33
#
# DJA with E1 (before H)
# P(0) c: 0.9999999999999996
# P(0) b: 1.0573994819069698e-33
#
# DJA with E2 (after first H)
# P(0) c: 0.9999999999999996
# P(0) b: 1.0573994819069698e-33
#
# DJA with E3 (after oracle)
# P(0) c: 0.9999999999999996
# P(0) b: 1.0573994819069698e-33
#
# DJA with E4 (after final H)
# P(0) c: 0.9999999999999996
# P(0) b: 1.0573994819069698e-33

# %%
# Parameters
n = 1
theta = np.pi / 4        
target_qubit = 0         
axis = (1, 0, 0)         


# Original Deutsch–Jozsa (no error)
const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_0)
bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(const, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(bal, n)

print("Original DJA")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()


# Error 1 (before Hadamards)
state_c1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c1, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b1, n)

print("DJA with E1 (before H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 2 (after first Hadamards)
state_c2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c2, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b2, n)

print("DJA with E2 (after first H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 3 (after oracle)
state_c3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c3, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b3, n)

print("DJA with E3 (after oracle)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 4 (after final Hadamards)
state_c4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c4, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b4, n)

print("DJA with E4 (after final H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
# Out:
# Original DJA
# P(0) c: 0.9999999999999996
# P(0) b: 1.0573994819069698e-33
#
# DJA with E1 (before H)
# P(0) c: 0.853553390593273
# P(0) b: 0.14644660940672613
#
# DJA with E2 (after first H)
# P(0) c: 0.9999999999999992
# P(0) b: 6.624483918491784e-36
#
# DJA with E3 (after oracle)
# P(0) c: 0.9999999999999992
# P(0) b: 6.624483918491784e-36
#
# DJA with E4 (after final H)
# P(0) c: 0.8535533905932733
# P(0) b: 0.14644660940672619

# %%
# Parameters
n = 1
theta = np.pi / 3       
target_qubit = 0         
axis = (1, 0, 0)         


# Original Deutsch–Jozsa (no error)
const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_0)
bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(const, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(bal, n)

print("Original DJA")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()


# Error 1 (before Hadamards)
state_c1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c1, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b1, n)

print("DJA with E1 (before H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 2 (after first Hadamards)
state_c2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c2, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b2, n)

print("DJA with E2 (after first H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 3 (after oracle)
state_c3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c3, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b3, n)

print("DJA with E3 (after oracle)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 4 (after final Hadamards)
state_c4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c4, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b4, n)

print("DJA with E4 (after final H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
# Out:
# Original DJA
# P(0) c: 0.9999999999999996
# P(0) b: 1.0573994819069698e-33
#
# DJA with E1 (before H)
# P(0) c: 0.7499999999999993
# P(0) b: 0.24999999999999972
#
# DJA with E2 (after first H)
# P(0) c: 0.9999999999999989
# P(0) b: 4.800044194835231e-34
#
# DJA with E3 (after oracle)
# P(0) c: 0.9999999999999989
# P(0) b: 4.800044194835231e-34
#
# DJA with E4 (after final H)
# P(0) c: 0.7499999999999996
# P(0) b: 0.2499999999999998

# %%
# Parameters
n = 1
theta = np.pi / 4        
target_qubit = 0         
axis = (1, 0, 0)         


# Original Deutsch–Jozsa (no error)
const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_0)
bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(const, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(bal, n)

print("Original DJA")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()


# Error 1 (before Hadamards)
state_c1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c1, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b1, n)

print("DJA with E1 (before H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 2 (after first Hadamards)
state_c2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c2, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b2, n)

print("DJA with E2 (after first H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 3 (after oracle)
state_c3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c3, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b3, n)

print("DJA with E3 (after oracle)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 4 (after final Hadamards)
state_c4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c4, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b4, n)

print("DJA with E4 (after final H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
# Out:
# Original DJA
# P(0) c: 0.9999999999999996
# P(0) b: 1.0573994819069698e-33
#
# DJA with E1 (before H)
# P(0) c: 0.853553390593273
# P(0) b: 0.14644660940672613
#
# DJA with E2 (after first H)
# P(0) c: 0.9999999999999992
# P(0) b: 6.624483918491784e-36
#
# DJA with E3 (after oracle)
# P(0) c: 0.9999999999999992
# P(0) b: 6.624483918491784e-36
#
# DJA with E4 (after final H)
# P(0) c: 0.8535533905932733
# P(0) b: 0.14644660940672619

# %%
# Parameters
n = 1
theta = np.pi       
target_qubit = 0         
axis = (1, 0, 0)         


# Original Deutsch–Jozsa (no error)
const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_0)
bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(const, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(bal, n)

print("Original DJA")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()


# Error 1 (before Hadamards)
state_c1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c1, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b1, n)

print("DJA with E1 (before H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 2 (after first Hadamards)
state_c2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c2, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b2, n)

print("DJA with E2 (after first H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 3 (after oracle)
state_c3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c3, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b3, n)

print("DJA with E3 (after oracle)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 4 (after final Hadamards)
state_c4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c4, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b4, n)

print("DJA with E4 (after final H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
# Out:
# Original DJA
# P(0) c: 0.9999999999999996
# P(0) b: 1.0573994819069698e-33
#
# DJA with E1 (before H)
# P(0) c: 4.806798938561611e-33
# P(0) b: 0.9999999999999996
#
# DJA with E2 (after first H)
# P(0) c: 0.9999999999999996
# P(0) b: 1.0573994819069698e-33
#
# DJA with E3 (after oracle)
# P(0) c: 0.9999999999999996
# P(0) b: 1.0573994819069698e-33
#
# DJA with E4 (after final H)
# P(0) c: 4.806798938561611e-33
# P(0) b: 0.9999999999999996

# %%
# Parameters
n = 1
theta = np.pi / 6        
target_qubit = 0         
axis = (1, 0, 0)         


# Original Deutsch–Jozsa (no error)
const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_0)
bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(const, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(bal, n)

print("Original DJA")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()


# Error 1 (before Hadamards)
state_c1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c1, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b1, n)

print("DJA with E1 (before H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 2 (after first Hadamards)
state_c2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c2, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b2, n)

print("DJA with E2 (after first H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 3 (after oracle)
state_c3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c3, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b3, n)

print("DJA with E3 (after oracle)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 4 (after final Hadamards)
state_c4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c4, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b4, n)

print("DJA with E4 (after final H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
# Out:
# Original DJA
# P(0) c: 0.9999999999999996
# P(0) b: 1.0573994819069698e-33
#
# DJA with E1 (before H)
# P(0) c: 0.933012701892219
# P(0) b: 0.06698729810778066
#
# DJA with E2 (after first H)
# P(0) c: 0.9999999999999996
# P(0) b: 1.4013804382147068e-34
#
# DJA with E3 (after oracle)
# P(0) c: 0.9999999999999996
# P(0) b: 1.4013804382147068e-34
#
# DJA with E4 (after final H)
# P(0) c: 0.9330127018922193
# P(0) b: 0.06698729810778066

# %%
n = 1
theta = np.pi / 2       
target_qubit = 0         
axis = (0, 0, 1)         

# no error
con = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_0)
bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(con, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(bal, n)

print("no error")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])

# Error 1 before Hadamards
state_c1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c1, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b1, n)

print("E1 (before H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()


# Error 2 after first Hadamards.
state_c2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c2, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b2, n)

print("E2 (after first H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()


# Error 3, after oracle
state_c3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c3, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b3, n)

print("E3 after oracle")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()


# Error after final Hadamards
state_c4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c4, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b4, n)

print("E4 after final H")
print("P(0) c:\n", probs_c[0])
print("P(0) b:\n", probs_b[0])
# Out:
# no error
# P(0) c: 0.9999999999999996
# P(0) b: 1.0573994819069698e-33
# E1 (before H)
# P(0) c: 0.9999999999999998
# P(0) b: 3.0171012341100246e-34
#
# E2 (after first H)
# P(0) c: 0.5
# P(0) b: 0.4999999999999998
#
# E3 after oracle
# P(0) c: 0.5
# P(0) b: 0.4999999999999998
#
# E4 after final H
# P(0) c:
#  0.9999999999999998
# P(0) b:
#  1.0573994819069704e-33

# %%
n = 2
theta = np.pi / 4        
target_qubit = 1       
axis = (1, 0, 0)         

# Original Deutsch–Jozsa (no error)
const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_0)
bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(const, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(bal, n)

print("Original DJA")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()


# Error 1 (before Hadamards)
state_c1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c1, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b1, n)

print("DJA with E1 (before H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 2 (after first Hadamards)
state_c2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c2, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b2, n)

print("DJA with E2 (after first H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 3 (after oracle)
state_c3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c3, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b3, n)

print("DJA with E3 (after oracle)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
print()

# Error 4 (after final Hadamards)
state_c4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_0, theta, target_qubit, axis)
state_b4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

probs_c = qa.deutsch_jozsa.measure_probs_first_n(state_c4, n)
probs_b = qa.deutsch_jozsa.measure_probs_first_n(state_b4, n)

print("DJA with E4 (after final H)")
print("P(0) c:", probs_c[0])
print("P(0) b:", probs_b[0])
# Out:
# Original DJA
# P(0) c: 0.9999999999999989
# P(0) b: 2.643498704767422e-34
#
# DJA with E1 (before H)
# P(0) c: 0.853553390593273
# P(0) b: 0.14644660940672613
#
# DJA with E2 (after first H)
# P(0) c: 0.9999999999999992
# P(0) b: 1.474152541086386e-34
#
# DJA with E3 (after oracle)
# P(0) c: 0.9999999999999992
# P(0) b: 1.474152541086386e-34
#
# DJA with E4 (after final H)
# P(0) c: 0.8535533905932726
# P(0) b: 0.14644660940672607

# %%
shots = 1024
n = 9
theta = np.pi / 4
target_qubit = 0
axis = (1, 0, 0)

state_const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_1)
state_bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)

samples_const = qa.deutsch_jozsa.sample_measurements_input(state_const, n, shots)
samples_bal   = qa.deutsch_jozsa.sample_measurements_input(state_bal, n, shots)

print("no errors")
print("cons:", samples_const)
print("bal:", samples_bal)
print()

state_const1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal1   = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const1 = qa.deutsch_jozsa.sample_measurements_input(state_const1, n, shots)
samples_bal1   = qa.deutsch_jozsa.sample_measurements_input(state_bal1, n, shots)

print("Error 1 (before Hadamards)")
print("constant:", samples_const1)
print("balanced:", samples_bal1)
print()

state_c2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_b2   = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_c2 = qa.deutsch_jozsa.sample_measurements_input(state_c2, n, shots)
samples_b2   = qa.deutsch_jozsa.sample_measurements_input(state_b2, n, shots)

print("Error 2 (after first Hadamards)")
print("sample for c2:", samples_c2)
print("sample for b2:", samples_b2)
print()

state_const3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal3   = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const3 = qa.deutsch_jozsa.sample_measurements_input(state_const3, n, shots)
samples_bal3   = qa.deutsch_jozsa.sample_measurements_input(state_bal3, n, shots)

print("Error 3 (after oracle)")
print("constant:", samples_const3)
print("balanced:", samples_bal3)
print()


state_c4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_b4   = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

samples_const4 = qa.deutsch_jozsa.sample_measurements_input(state_c4, n, shots)
samples_bal4   = qa.deutsch_jozsa.sample_measurements_input(state_b4, n, shots)

print("after final Hadamards")
print("constant:", samples_const4)
print("balanced:", samples_bal4)
# Out:
# no errors
# cons: Counter({0: 1024})
# bal: Counter({1: 1024})
#
# Error 1 (before Hadamards)
# constant: Counter({0: 867, 256: 157})
# balanced: Counter({1: 883, 257: 141})
#
# Error 2 (after first Hadamards)
# sample for c2: Counter({0: 1024})
# sample for b2: Counter({1: 1024})
#
# Error 3 (after oracle)
# constant: Counter({0: 1024})
# balanced: Counter({1: 1024})
#
# after final Hadamards
# constant: Counter({0: 886, 256: 138})
# balanced: Counter({1: 868, 257: 156})

# %%
shots = 1024
n = 9
theta = np.pi / 4
target_qubit = 3
axis = (1, 0, 0)

state_const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_1)
state_bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
samples_const = qa.deutsch_jozsa.sample_measurements_input(state_const, n, shots)
samples_bal   = qa.deutsch_jozsa.sample_measurements_input(state_bal, n, shots)

print("Original DJA")
print("constant:", samples_const)
print("balanced:", samples_bal)
print()

state_const1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal1   = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const1 = qa.deutsch_jozsa.sample_measurements_input(state_const1, n, shots)
samples_bal1   = qa.deutsch_jozsa.sample_measurements_input(state_bal1, n, shots)

print("Error 1 (before Hadamards)")
print("constant:", samples_const1)
print("balanced:", samples_bal1)
print()

state_const2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal2   = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const2 = qa.deutsch_jozsa.sample_measurements_input(state_const2, n, shots)
samples_bal2   = qa.deutsch_jozsa.sample_measurements_input(state_bal2, n, shots)

print("Error 2 (after first Hadamards)")
print("constant:", samples_const2)
print("balanced:", samples_bal2)
print()

state_const3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal3   = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const3 = qa.deutsch_jozsa.sample_measurements_input(state_const3, n, shots)
samples_bal3   = qa.deutsch_jozsa.sample_measurements_input(state_bal3, n, shots)
print("Error 3 (after oracle)")
print("constant:", samples_const3)
print("balanced:", samples_bal3)
print()
state_const4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal4   = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const4 = qa.deutsch_jozsa.sample_measurements_input(state_const4, n, shots)
samples_bal4   = qa.deutsch_jozsa.sample_measurements_input(state_bal4, n, shots)
print("Error 4 (after final Hadamards)")
print("constant:", samples_const4)
print("balanced:", samples_bal4)
# Out:
# Original DJA
# constant: Counter({0: 1024})
# balanced: Counter({1: 1024})
#
# Error 1 (before Hadamards)
# constant: Counter({0: 880, 32: 144})
# balanced: Counter({1: 873, 33: 151})
#
# Error 2 (after first Hadamards)
# constant: Counter({0: 1024})
# balanced: Counter({1: 1024})
#
# Error 3 (after oracle)
# constant: Counter({0: 1024})
# balanced: Counter({1: 1024})
#
# Error 4 (after final Hadamards)
# constant: Counter({0: 870, 32: 154})
# balanced: Counter({1: 864, 33: 160})

# %%
shots = 1024
n = 9
theta = np.pi / 4
target_qubit = 8
axis = (1, 0, 0)

state_const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_1)
state_bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
samples_const = qa.deutsch_jozsa.sample_measurements_input(state_const, n, shots)
samples_bal   = qa.deutsch_jozsa.sample_measurements_input(state_bal, n, shots)

print("Original DJA")
print("constant:", samples_const)
print("balanced:", samples_bal)
print()

state_const1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal1   = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const1 = qa.deutsch_jozsa.sample_measurements_input(state_const1, n, shots)
samples_bal1   = qa.deutsch_jozsa.sample_measurements_input(state_bal1, n, shots)

print("Error 1 (before Hadamards)")
print("constant:", samples_const1)
print("balanced:", samples_bal1)
print()

state_const2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal2   = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const2 = qa.deutsch_jozsa.sample_measurements_input(state_const2, n, shots)
samples_bal2   = qa.deutsch_jozsa.sample_measurements_input(state_bal2, n, shots)

print("Error 2 (after first Hadamards)")
print("constant:", samples_const2)
print("balanced:", samples_bal2)
print()

state_const3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal3   = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

samples_const3 = qa.deutsch_jozsa.sample_measurements_input(state_const3, n, shots)
samples_bal3   = qa.deutsch_jozsa.sample_measurements_input(state_bal3, n, shots)

print("Error 3 (after oracle)")
print("constant:", samples_const3)
print("balanced:", samples_bal3)
print()


state_const4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal4   = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const4 = qa.deutsch_jozsa.sample_measurements_input(state_const4, n, shots)
samples_bal4   = qa.deutsch_jozsa.sample_measurements_input(state_bal4, n, shots)

print("Error 4 (after final Hadamards)")
print("constant:", samples_const4)
print("balanced:", samples_bal4)
# Out:
# Original DJA
# constant: Counter({0: 1024})
# balanced: Counter({1: 1024})
#
# Error 1 (before Hadamards)
# constant: Counter({0: 874, 1: 150})
# balanced: Counter({1: 885, 0: 139})
#
# Error 2 (after first Hadamards)
# constant: Counter({0: 1024})
# balanced: Counter({1: 1024})
#
# Error 3 (after oracle)
# constant: Counter({0: 1024})
# balanced: Counter({1: 1024})
#
# Error 4 (after final Hadamards)
# constant: Counter({0: 896, 1: 128})
# balanced: Counter({1: 863, 0: 161})

# %%
shots = 1024
n = 9
theta = np.pi / 4
target_qubit = 7
axis = (1, 0, 0)

state_const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_1)
state_bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)

samples_const = qa.deutsch_jozsa.sample_measurements_input(state_const, n, shots)
samples_bal   = qa.deutsch_jozsa.sample_measurements_input(state_bal, n, shots)

print("Original DJA")
print("constant:", samples_const)
print("balanced:", samples_bal)
print()

state_const1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal1   = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const1 = qa.deutsch_jozsa.sample_measurements_input(state_const1, n, shots)
samples_bal1   = qa.deutsch_jozsa.sample_measurements_input(state_bal1, n, shots)

print("Error 1 (before Hadamards)")
print("constant:", samples_const1)
print("balanced:", samples_bal1)
print()

state_const2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal2   = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const2 = qa.deutsch_jozsa.sample_measurements_input(state_const2, n, shots)
samples_bal2   = qa.deutsch_jozsa.sample_measurements_input(state_bal2, n, shots)

print("Error 2 (after first Hadamards)")
print("constant:", samples_const2)
print("balanced:", samples_bal2)
print()

state_const3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal3   = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const3 = qa.deutsch_jozsa.sample_measurements_input(state_const3, n, shots)
samples_bal3   = qa.deutsch_jozsa.sample_measurements_input(state_bal3, n, shots)

print("Error 3 (after oracle)")
print("constant:", samples_const3)
print("balanced:", samples_bal3)
print()


state_const4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal4   = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const4 = qa.deutsch_jozsa.sample_measurements_input(state_const4, n, shots)
samples_bal4   = qa.deutsch_jozsa.sample_measurements_input(state_bal4, n, shots)

print("Error 4 (after final Hadamards)")
print("constant:", samples_const4)
print("balanced:", samples_bal4)
# Out:
# Original DJA
# constant: Counter({0: 1024})
# balanced: Counter({1: 1024})
#
# Error 1 (before Hadamards)
# constant: Counter({0: 862, 2: 162})
# balanced: Counter({1: 886, 3: 138})
#
# Error 2 (after first Hadamards)
# constant: Counter({0: 1024})
# balanced: Counter({1: 1024})
#
# Error 3 (after oracle)
# constant: Counter({0: 1024})
# balanced: Counter({1: 1024})
#
# Error 4 (after final Hadamards)
# constant: Counter({0: 879, 2: 145})
# balanced: Counter({1: 886, 3: 138})

# %%
shots = 1024
n = 9
theta = np.pi / 4
target_qubit = 0
axis = (1, 0, 0)

state_const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_1)
state_bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
samples_const = qa.deutsch_jozsa.sample_measurements_input(state_const, n, shots)
samples_bal   = qa.deutsch_jozsa.sample_measurements_input(state_bal, n, shots)

print("Original DJA")
print("constant:", samples_const)
print("balanced:", samples_bal)
print()

state_const1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal1   = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const1 = qa.deutsch_jozsa.sample_measurements_input(state_const1, n, shots)
samples_bal1   = qa.deutsch_jozsa.sample_measurements_input(state_bal1, n, shots)

print("Error 1 (before Hadamards)")
print("constant:", samples_const1)
print("balanced:", samples_bal1)
print()

state_const2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal2   = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

samples_const2 = qa.deutsch_jozsa.sample_measurements_input(state_const2, n, shots)
samples_bal2   = qa.deutsch_jozsa.sample_measurements_input(state_bal2, n, shots)

print("Error 2 (after first Hadamards)")
print("constant:", samples_const2)
print("balanced:", samples_bal2)
print()

state_const3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal3   = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const3 = qa.deutsch_jozsa.sample_measurements_input(state_const3, n, shots)
samples_bal3   = qa.deutsch_jozsa.sample_measurements_input(state_bal3, n, shots)

print("Error 3 (after oracle)")
print("constant:", samples_const3)
print("balanced:", samples_bal3)
print()


state_const4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal4   = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const4 = qa.deutsch_jozsa.sample_measurements_input(state_const4, n, shots)
samples_bal4   = qa.deutsch_jozsa.sample_measurements_input(state_bal4, n, shots)

print("Error 4 (after final Hadamards)")
print("constant:", samples_const4)
print("balanced:", samples_bal4)
# Out:
# Original DJA
# constant: Counter({0: 1024})
# balanced: Counter({1: 1024})
#
# Error 1 (before Hadamards)
# constant: Counter({0: 871, 256: 153})
# balanced: Counter({1: 886, 257: 138})
#
# Error 2 (after first Hadamards)
# constant: Counter({0: 1024})
# balanced: Counter({1: 1024})
#
# Error 3 (after oracle)
# constant: Counter({0: 1024})
# balanced: Counter({1: 1024})
#
# Error 4 (after final Hadamards)
# constant: Counter({0: 883, 256: 141})
# balanced: Counter({1: 870, 257: 154})

# %%
shots = 2000
n = 11
theta = np.pi / 4
target_qubit = 0
axis = (1, 0, 0)

state_const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_1)
state_bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
samples_const = qa.deutsch_jozsa.sample_measurements_input(state_const, n, shots)
samples_bal   = qa.deutsch_jozsa.sample_measurements_input(state_bal, n, shots)

print("Original DJA")
print("constant:", samples_const)
print("balanced:", samples_bal)
print()

state_const1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal1   = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const1 = qa.deutsch_jozsa.sample_measurements_input(state_const1, n, shots)
samples_bal1   = qa.deutsch_jozsa.sample_measurements_input(state_bal1, n, shots)

print("Error 1 (before Hadamards)")
print("constant:", samples_const1)
print("balanced:", samples_bal1)
print()

state_const2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal2   = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const2 = qa.deutsch_jozsa.sample_measurements_input(state_const2, n, shots)
samples_bal2   = qa.deutsch_jozsa.sample_measurements_input(state_bal2, n, shots)

print("Error 2 (after first Hadamards)")
print("constant:", samples_const2)
print("balanced:", samples_bal2)
print()

state_const3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal3   = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const3 = qa.deutsch_jozsa.sample_measurements_input(state_const3, n, shots)
samples_bal3   = qa.deutsch_jozsa.sample_measurements_input(state_bal3, n, shots)

print("Error 3 (after oracle)")
print("constant:", samples_const3)
print("balanced:", samples_bal3)
print()


state_const4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal4   = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)

samples_const4 = qa.deutsch_jozsa.sample_measurements_input(state_const4, n, shots)
samples_bal4   = qa.deutsch_jozsa.sample_measurements_input(state_bal4, n, shots)

print("Error 4 (after final Hadamards)")
print("constant:", samples_const4)
print("balanced:", samples_bal4)
# Out:
# Original DJA
# constant: Counter({0: 2000})
# balanced: Counter({1: 2000})
#
# Error 1 (before Hadamards)
# constant: Counter({0: 1684, 1024: 316})
# balanced: Counter({1: 1709, 1025: 291})
#
# Error 2 (after first Hadamards)
# constant: Counter({0: 2000})
# balanced: Counter({1: 2000})
#
# Error 3 (after oracle)
# constant: Counter({0: 2000})
# balanced: Counter({1: 2000})
#
# Error 4 (after final Hadamards)
# constant: Counter({0: 1712, 1024: 288})
# balanced: Counter({1: 1693, 1025: 307})

# %%
shots = 2000
n = 11
theta = np.pi / 4
target_qubit = 5
axis = (1, 0, 0)

state_const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_1)
state_bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
samples_const = qa.deutsch_jozsa.sample_measurements_input(state_const, n, shots)
samples_bal   = qa.deutsch_jozsa.sample_measurements_input(state_bal, n, shots)

print("Original DJA")
print("constant:", samples_const)
print("balanced:", samples_bal)
print()

state_const1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal1   = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const1 = qa.deutsch_jozsa.sample_measurements_input(state_const1, n, shots)
samples_bal1   = qa.deutsch_jozsa.sample_measurements_input(state_bal1, n, shots)

print("Error 1 (before Hadamards)")
print("constant:", samples_const1)
print("balanced:", samples_bal1)
print()

state_const2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal2   = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const2 = qa.deutsch_jozsa.sample_measurements_input(state_const2, n, shots)
samples_bal2   = qa.deutsch_jozsa.sample_measurements_input(state_bal2, n, shots)

print("Error 2 (after first Hadamards)")
print("constant:", samples_const2)
print("balanced:", samples_bal2)
print()

state_const3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal3   = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const3 = qa.deutsch_jozsa.sample_measurements_input(state_const3, n, shots)
samples_bal3   = qa.deutsch_jozsa.sample_measurements_input(state_bal3, n, shots)

print("Error 3 (after oracle)")
print("constant:", samples_const3)
print("balanced:", samples_bal3)
print()


state_const4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal4   = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const4 = qa.deutsch_jozsa.sample_measurements_input(state_const4, n, shots)
samples_bal4   = qa.deutsch_jozsa.sample_measurements_input(state_bal4, n, shots)

print("Error 4 (after final Hadamards)")
print("constant:", samples_const4)
print("balanced:", samples_bal4)
# Out:
# Original DJA
# constant: Counter({0: 2000})
# balanced: Counter({1: 2000})
#
# Error 1 (before Hadamards)
# constant: Counter({0: 1702, 32: 298})
# balanced: Counter({1: 1697, 33: 303})
#
# Error 2 (after first Hadamards)
# constant: Counter({0: 2000})
# balanced: Counter({1: 2000})
#
# Error 3 (after oracle)
# constant: Counter({0: 2000})
# balanced: Counter({1: 2000})
#
# Error 4 (after final Hadamards)
# constant: Counter({0: 1704, 32: 296})
# balanced: Counter({1: 1698, 33: 302})

# %%
shots = 2000
n = 11
theta = np.pi / 4
target_qubit = 10
axis = (1, 0, 0)

state_const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_1)
state_bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
samples_const = qa.deutsch_jozsa.sample_measurements_input(state_const, n, shots)
samples_bal   = qa.deutsch_jozsa.sample_measurements_input(state_bal, n, shots)

print("Original DJA")
print("constant:", samples_const)
print("balanced:", samples_bal)
print()

state_const1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal1   = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const1 = qa.deutsch_jozsa.sample_measurements_input(state_const1, n, shots)
samples_bal1   = qa.deutsch_jozsa.sample_measurements_input(state_bal1, n, shots)

print("Error 1 (before Hadamards)")
print("constant:", samples_const1)
print("balanced:", samples_bal1)
print()

state_const2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal2   = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const2 = qa.deutsch_jozsa.sample_measurements_input(state_const2, n, shots)
samples_bal2   = qa.deutsch_jozsa.sample_measurements_input(state_bal2, n, shots)

print("Error 2 (after first Hadamards)")
print("constant:", samples_const2)
print("balanced:", samples_bal2)
print()

state_const3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal3   = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const3 = qa.deutsch_jozsa.sample_measurements_input(state_const3, n, shots)
samples_bal3   = qa.deutsch_jozsa.sample_measurements_input(state_bal3, n, shots)

print("Error 3 (after oracle)")
print("constant:", samples_const3)
print("balanced:", samples_bal3)
print()

state_const4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal4   = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const4 = qa.deutsch_jozsa.sample_measurements_input(state_const4, n, shots)
samples_bal4   = qa.deutsch_jozsa.sample_measurements_input(state_bal4, n, shots)

print("Error 4 (after final Hadamards)")
print("constant:", samples_const4)
print("balanced:", samples_bal4)
# Out:
# Original DJA
# constant: Counter({0: 2000})
# balanced: Counter({1: 2000})
#
# Error 1 (before Hadamards)
# constant: Counter({0: 1717, 1: 283})
# balanced: Counter({1: 1715, 0: 285})
#
# Error 2 (after first Hadamards)
# constant: Counter({0: 2000})
# balanced: Counter({1: 2000})
#
# Error 3 (after oracle)
# constant: Counter({0: 2000})
# balanced: Counter({1: 2000})
#
# Error 4 (after final Hadamards)
# constant: Counter({0: 1704, 1: 296})
# balanced: Counter({1: 1705, 0: 295})

# %%
shots = 3000
n = 7
theta = np.pi / 4
target_qubit = 5
axis = (1, 0, 0)

state_const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_1)
state_bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
samples_const = qa.deutsch_jozsa.sample_measurements_input(state_const, n, shots)
samples_bal   = qa.deutsch_jozsa.sample_measurements_input(state_bal, n, shots)

print("Original DJA")
print("constant:", samples_const)
print("balanced:", samples_bal)
print()

state_const1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal1   = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const1 = qa.deutsch_jozsa.sample_measurements_input(state_const1, n, shots)
samples_bal1   = qa.deutsch_jozsa.sample_measurements_input(state_bal1, n, shots)

print("Error 1 (before Hadamards)")
print("constant:", samples_const1)
print("balanced:", samples_bal1)
print()

state_const2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal2   = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const2 = qa.deutsch_jozsa.sample_measurements_input(state_const2, n, shots)
samples_bal2   = qa.deutsch_jozsa.sample_measurements_input(state_bal2, n, shots)

print("Error 2 (after first Hadamards)")
print("constant:", samples_const2)
print("balanced:", samples_bal2)
print()

state_const3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal3   = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const3 = qa.deutsch_jozsa.sample_measurements_input(state_const3, n, shots)
samples_bal3   = qa.deutsch_jozsa.sample_measurements_input(state_bal3, n, shots)

print("Error 3 (after oracle)")
print("constant:", samples_const3)
print("balanced:", samples_bal3)
print()


state_const4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal4   = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const4 = qa.deutsch_jozsa.sample_measurements_input(state_const4, n, shots)
samples_bal4   = qa.deutsch_jozsa.sample_measurements_input(state_bal4, n, shots)

print("Error 4 (after final Hadamards)")
print("constant:", samples_const4)
print("balanced:", samples_bal4)
# Out:
# Original DJA
# constant: Counter({0: 3000})
# balanced: Counter({1: 3000})
#
# Error 1 (before Hadamards)
# constant: Counter({0: 2595, 2: 405})
# balanced: Counter({1: 2593, 3: 407})
#
# Error 2 (after first Hadamards)
# constant: Counter({0: 3000})
# balanced: Counter({1: 3000})
#
# Error 3 (after oracle)
# constant: Counter({0: 3000})
# balanced: Counter({1: 3000})
#
# Error 4 (after final Hadamards)
# constant: Counter({0: 2533, 2: 467})
# balanced: Counter({1: 2555, 3: 445})

# %%
shots = 7000
n = 6
theta = np.pi / 4
target_qubit = 0
axis = (1, 0, 0)

state_const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_1)
state_bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
samples_const = qa.deutsch_jozsa.sample_measurements_input(state_const, n, shots)
samples_bal   = qa.deutsch_jozsa.sample_measurements_input(state_bal, n, shots)

print("Original DJA")
print("constant:", samples_const)
print("balanced:", samples_bal)
print()

state_const1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal1   = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const1 = qa.deutsch_jozsa.sample_measurements_input(state_const1, n, shots)
samples_bal1   = qa.deutsch_jozsa.sample_measurements_input(state_bal1, n, shots)

print("Error 1 (before Hadamards)")
print("constant:", samples_const1)
print("balanced:", samples_bal1)
print()

state_const2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal2   = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const2 = qa.deutsch_jozsa.sample_measurements_input(state_const2, n, shots)
samples_bal2   = qa.deutsch_jozsa.sample_measurements_input(state_bal2, n, shots)

print("Error 2 (after first Hadamards)")
print("constant:", samples_const2)
print("balanced:", samples_bal2)
print()

state_const3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal3   = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const3 = qa.deutsch_jozsa.sample_measurements_input(state_const3, n, shots)
samples_bal3   = qa.deutsch_jozsa.sample_measurements_input(state_bal3, n, shots)

print("Error 3 (after oracle)")
print("constant:", samples_const3)
print("balanced:", samples_bal3)
print()

state_const4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal4   = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const4 = qa.deutsch_jozsa.sample_measurements_input(state_const4, n, shots)
samples_bal4   = qa.deutsch_jozsa.sample_measurements_input(state_bal4, n, shots)

print("Error 4 (after final Hadamards)")
print("constant:", samples_const4)
print("balanced:", samples_bal4)
# Out:
# Original DJA
# constant: Counter({0: 7000})
# balanced: Counter({1: 7000})
#
# Error 1 (before Hadamards)
# constant: Counter({0: 5935, 32: 1065})
# balanced: Counter({1: 5976, 33: 1024})
#
# Error 2 (after first Hadamards)
# constant: Counter({0: 7000})
# balanced: Counter({1: 7000})
#
# Error 3 (after oracle)
# constant: Counter({0: 7000})
# balanced: Counter({1: 7000})
#
# Error 4 (after final Hadamards)
# constant: Counter({0: 5972, 32: 1028})
# balanced: Counter({1: 5956, 33: 1044})

# %%
shots = 10000
n = 9
theta = np.pi / 4
target_qubit = 0
axis = (1, 0, 0)

state_const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_1)
state_bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
samples_const = qa.deutsch_jozsa.sample_measurements_input(state_const, n, shots)
samples_bal   = qa.deutsch_jozsa.sample_measurements_input(state_bal, n, shots)

print("Original DJA")
print("constant:", samples_const)
print("balanced:", samples_bal)
print()

state_const1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal1   = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const1 = qa.deutsch_jozsa.sample_measurements_input(state_const1, n, shots)
samples_bal1   = qa.deutsch_jozsa.sample_measurements_input(state_bal1, n, shots)

print("Error 1 (before Hadamards)")
print("constant:", samples_const1)
print("balanced:", samples_bal1)
print()

state_const2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal2   = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const2 = qa.deutsch_jozsa.sample_measurements_input(state_const2, n, shots)
samples_bal2   = qa.deutsch_jozsa.sample_measurements_input(state_bal2, n, shots)

print("Error 2 (after first Hadamards)")
print("constant:", samples_const2)
print("balanced:", samples_bal2)
print()

state_const3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal3   = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const3 = qa.deutsch_jozsa.sample_measurements_input(state_const3, n, shots)
samples_bal3   = qa.deutsch_jozsa.sample_measurements_input(state_bal3, n, shots)

print("Error 3 (after oracle)")
print("constant:", samples_const3)
print("balanced:", samples_bal3)
print()


state_const4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal4   = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const4 = qa.deutsch_jozsa.sample_measurements_input(state_const4, n, shots)
samples_bal4   = qa.deutsch_jozsa.sample_measurements_input(state_bal4, n, shots)

print("Error 4 (after final Hadamards)")
print("constant:", samples_const4)
print("balanced:", samples_bal4)
# Out:
# Original DJA
# constant: Counter({0: 10000})
# balanced: Counter({1: 10000})
#
# Error 1 (before Hadamards)
# constant: Counter({0: 8529, 256: 1471})
# balanced: Counter({1: 8584, 257: 1416})
#
# Error 2 (after first Hadamards)
# constant: Counter({0: 10000})
# balanced: Counter({1: 10000})
#
# Error 3 (after oracle)
# constant: Counter({0: 10000})
# balanced: Counter({1: 10000})
#
# Error 4 (after final Hadamards)
# constant: Counter({0: 8595, 256: 1405})
# balanced: Counter({1: 8508, 257: 1492})

# %%
shots = 10000
n = 9
theta = np.pi / 4
target_qubit = 5
axis = (1, 0, 0)

state_const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_1)
state_bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)
samples_const = qa.deutsch_jozsa.sample_measurements_input(state_const, n, shots)
samples_bal   = qa.deutsch_jozsa.sample_measurements_input(state_bal, n, shots)

print("Original DJA")
print("constant:", samples_const)
print("balanced:", samples_bal)
print()

state_const1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal1   = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const1 = qa.deutsch_jozsa.sample_measurements_input(state_const1, n, shots)
samples_bal1   = qa.deutsch_jozsa.sample_measurements_input(state_bal1, n, shots)

print("Error 1 (before Hadamards)")
print("constant:", samples_const1)
print("balanced:", samples_bal1)
print()

state_const2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal2   = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const2 = qa.deutsch_jozsa.sample_measurements_input(state_const2, n, shots)
samples_bal2   = qa.deutsch_jozsa.sample_measurements_input(state_bal2, n, shots)

print("Error 2 (after first Hadamards)")
print("constant:", samples_const2)
print("balanced:", samples_bal2)
print()

state_const3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal3   = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const3 = qa.deutsch_jozsa.sample_measurements_input(state_const3, n, shots)
samples_bal3   = qa.deutsch_jozsa.sample_measurements_input(state_bal3, n, shots)

print("Error 3 (after oracle)")
print("constant:", samples_const3)
print("balanced:", samples_bal3)
print()


state_const4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal4   = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const4 = qa.deutsch_jozsa.sample_measurements_input(state_const4, n, shots)
samples_bal4   = qa.deutsch_jozsa.sample_measurements_input(state_bal4, n, shots)

print("Error 4 (after final Hadamards)")
print("constant:", samples_const4)
print("balanced:", samples_bal4)
# Out:
# Original DJA
# constant: Counter({0: 10000})
# balanced: Counter({1: 10000})
#
# Error 1 (before Hadamards)
# constant: Counter({0: 8560, 8: 1440})
# balanced: Counter({1: 8544, 9: 1456})
#
# Error 2 (after first Hadamards)
# constant: Counter({0: 10000})
# balanced: Counter({1: 10000})
#
# Error 3 (after oracle)
# constant: Counter({0: 10000})
# balanced: Counter({1: 10000})
#
# Error 4 (after final Hadamards)
# constant: Counter({0: 8576, 8: 1424})
# balanced: Counter({1: 8589, 9: 1411})

# %%
shots = 10000
n = 9
theta = np.pi / 4
target_qubit = 8
axis = (1, 0, 0)

state_const = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_constant_1)
state_bal   = qa.deutsch_jozsa.deutsch_jozsa(n, qa.deutsch_jozsa.f_balanced_parity)

samples_const = qa.deutsch_jozsa.sample_measurements_input(state_const, n, shots)
samples_bal   = qa.deutsch_jozsa.sample_measurements_input(state_bal, n, shots)

print("Original DJA")
print("constant:", samples_const)
print("balanced:", samples_bal)
print()

state_const1 = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal1   = qa.deutsch_jozsa.deutsch_jozsa_error1(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const1 = qa.deutsch_jozsa.sample_measurements_input(state_const1, n, shots)
samples_bal1   = qa.deutsch_jozsa.sample_measurements_input(state_bal1, n, shots)

print("Error 1 (before Hadamards)")
print("constant:", samples_const1)
print("balanced:", samples_bal1)
print()

state_const2 = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal2   = qa.deutsch_jozsa.deutsch_jozsa_error2(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const2 = qa.deutsch_jozsa.sample_measurements_input(state_const2, n, shots)
samples_bal2   = qa.deutsch_jozsa.sample_measurements_input(state_bal2, n, shots)

print("Error 2 (after first Hadamards)")
print("constant:", samples_const2)
print("balanced:", samples_bal2)
print()

state_const3 = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal3   = qa.deutsch_jozsa.deutsch_jozsa_error3(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const3 = qa.deutsch_jozsa.sample_measurements_input(state_const3, n, shots)
samples_bal3   = qa.deutsch_jozsa.sample_measurements_input(state_bal3, n, shots)

print("Error 3 (after oracle)")
print("constant:", samples_const3)
print("balanced:", samples_bal3)
print()


state_const4 = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_constant_1, theta, target_qubit, axis)
state_bal4   = qa.deutsch_jozsa.deutsch_jozsa_error4(n, qa.deutsch_jozsa.f_balanced_parity, theta, target_qubit, axis)
samples_const4 = qa.deutsch_jozsa.sample_measurements_input(state_const4, n, shots)
samples_bal4   = qa.deutsch_jozsa.sample_measurements_input(state_bal4, n, shots)

print("Error 4 (after final Hadamards)")
print("constant:", samples_const4)
print("balanced:", samples_bal4)
# Out:
# Original DJA
# constant: Counter({0: 10000})
# balanced: Counter({1: 10000})
#
# Error 1 (before Hadamards)
# constant: Counter({0: 8594, 1: 1406})
# balanced: Counter({1: 8518, 0: 1482})
#
# Error 2 (after first Hadamards)
# constant: Counter({0: 10000})
# balanced: Counter({1: 10000})
#
# Error 3 (after oracle)
# constant: Counter({0: 10000})
# balanced: Counter({1: 10000})
#
# Error 4 (after final Hadamards)
# constant: Counter({0: 8550, 1: 1450})
# balanced: Counter({1: 8525, 0: 1475})

# %% [markdown]
# ### Simulating Measurements
#
# The missing element of our quantum computer simulator is the measurement step. In the case we considered above, the output state was always one of the states of the computational basis, i.e. a "classical state" (and not entangled), but in general we end up with superpositions and the outcome of a measurement is random. This randomness we also want to implement in our quantum computer simulator. To do so, we can calculate the probabilities of all basis states and then randomly choose one of these outcomes according to this distribution. Write a function that takes a state $|\psi\rangle$ (i.e. its coefficient vector in the computational basis) as input and outputs one of the computational basis states as the measurement result. You may find the functions `random.rand` and `cumsum` from numpy helpful.
#
# Test your function on some example states, for example you could create an equal superposition of all basis states by applying Hadamard gates to all qubits.
#
# Apply an $R_x$ rotation to single qubit initially in state $|0\rangle$ using various angles between 0 and $\pi$ and simulate $z$-basis meaurements. Evaluate the expectation value of $Z$ from these measuremets. For what angle are the statistical fluctuations compared to the exact expextation value the largest?
