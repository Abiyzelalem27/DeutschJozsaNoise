# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import quantum_algorithms as qa

# %%
# Common settings

shots = 1024
n_values = [1, 3, 5, 7, 9]
theta_values = np.radians(np.arange(0, 181, 10))

# Functions
functions = {
    "constant_0": qa.deutsch_jozsa.f_constant_0,
    "constant_1": qa.deutsch_jozsa.f_constant_1,
    "balanced": qa.deutsch_jozsa.f_balanced_parity,
}

# Rotation axes
axes = {
    "X": (1, 0, 0),
    "Y": (0, 1, 0),
    "Z": (0, 0, 1),
}

# Error locations
error_positions = {
    "E1_before_H": qa.deutsch_jozsa.deutsch_jozsa_error1,
    "E2_after_first_H": qa.deutsch_jozsa.deutsch_jozsa_error2,
    "E3_after_oracle": qa.deutsch_jozsa.deutsch_jozsa_error3,
    "E4_after_final_H": qa.deutsch_jozsa.deutsch_jozsa_error4,
}


label_map = {
    "no_error": "No Error",
    "E1_before_H": r"$\mathcal{E}_1$ before first $H$",
    "E2_after_first_H": r"$\mathcal{E}_2$ after first $H$",
    "E3_after_oracle": r"$\mathcal{E}_3$ after oracle",
    "E4_after_final_H": r"$\mathcal{E}_4$ after final $H$",
}

# %%
# Functions
functions = {
    "constant_0": qa.deutsch_jozsa.f_constant_0,
    "constant_1": qa.deutsch_jozsa.f_constant_1,
    "balanced": qa.deutsch_jozsa.f_balanced_parity,
}

# Full Experiment
start_time = time.time()
rng = np.random.default_rng(12345)
results = []

for n in n_values:
    print(f"Running n = {n}")

    for theta in theta_values:
        theta_deg = np.degrees(theta)

        for axis_name, axis in axes.items():
            for target_qubit in range(n):

                for function_name, f in functions.items():

                    # Run ideal circuit without error
                    state_ideal = qa.deutsch_jozsa.deutsch_jozsa(n, f)

                    samples_ideal = qa.deutsch_jozsa.sample_measurements_input(
                        state_ideal, n, shots, rng
                    )

                    P0_ideal = samples_ideal[0] / shots

                    if function_name.startswith("constant"):
                        success_ideal = P0_ideal
                    else:
                        success_ideal = 1 - P0_ideal

                    results.append({
                        "n": n,
                        "theta_rad": theta,
                        "theta_deg": theta_deg,
                        "axis": axis_name,
                        "target_qubit": target_qubit,
                        "function": function_name,
                        "error_position": "no_error",
                        "P0": P0_ideal,
                        "success": success_ideal,
                        "shots": shots,
                    })

                    # Run circuits with localized rotation errors
                    for error_name, error_function in error_positions.items():

                        state_error = error_function(
                            n=n,
                            f=f,
                            theta=theta,
                            target_qubit=target_qubit,
                            axis=axis,
                        )

                        samples_error = qa.deutsch_jozsa.sample_measurements_input(
                            state_error, n, shots, rng
                        )

                        P0_error = samples_error[0] / shots

                        if function_name.startswith("constant"):
                            success_error = P0_error
                        else:
                            success_error = 1 - P0_error

                        results.append({
                            "n": n,
                            "theta_rad": theta,
                            "theta_deg": theta_deg,
                            "axis": axis_name,
                            "target_qubit": target_qubit,
                            "function": function_name,
                            "error_position": error_name,
                            "P0": P0_error,
                            "success": success_error,
                            "shots": shots,
                        })

end_time = time.time()

df = pd.DataFrame(results)
# Out:
# Running n = 1
# Running n = 3
# Running n = 5
# Running n = 7
# Running n = 9

# %%
qa.plotting.plot_average_success(df, 9, "X", 3, "constant_0", 1024)
qa.plotting.plot_average_success(df, 9, "X", 3, "constant_1", 1024)
qa.plotting.plot_average_success(df, 9, "X", 3, "balanced", 1024)

# %%
qa.plotting.plot_average_success(df, 9, "X", 4, "constant_0", 1024)
qa.plotting.plot_average_success(df, 9, "X", 4, "constant_1", 1024)
qa.plotting.plot_average_success(df, 9, "X", 4, "balanced", 1024)

# %%
# n = 7, target = 5, Z-axis
qa.plotting.plot_average_success(df, 7, "Z", 5, "constant_0", 1024)
qa.plotting.plot_average_success(df, 7, "Z", 5, "constant_1", 1024)
qa.plotting.plot_average_success(df, 7, "Z", 5, "balanced", 1024)

# n = 9, target = 7, Z-axis
qa.plotting.plot_average_success(df, 9, "Z", 7, "constant_0", 1024)
qa.plotting.plot_average_success(df, 9, "Z", 7, "constant_1", 1024)
qa.plotting.plot_average_success(df, 9, "Z", 7, "balanced", 1024)

# %%
# n = 7, Y-axis, target qubit = 5

qa.plotting.plot_average_success(df, 7, "Y", 5, "constant_0", 1024)
qa.plotting.plot_average_success(df, 7, "Y", 5, "constant_1", 1024)
qa.plotting.plot_average_success(df, 7, "Y", 5, "balanced", 1024)

# n = 9, Y-axis, target qubit = 7

qa.plotting.plot_average_success(df, 9, "Y", 7, "constant_0", 1024)
qa.plotting.plot_average_success(df, 9, "Y", 7, "constant_1", 1024)
qa.plotting.plot_average_success(df, 9, "Y", 7, "balanced", 1024)

# %%
# constant_0
qa.plotting.plot_scalability(df, 0, "X", "E3_after_oracle", "constant_0", 1024)
qa.plotting.plot_scalability(df, 0, "Y", "E3_after_oracle", "constant_0", 1024)
qa.plotting.plot_scalability(df, 0, "Z", "E3_after_oracle", "constant_0", 1024)

# constant_1
qa.plotting.plot_scalability(df, 0, "X", "E3_after_oracle", "constant_1", 1024)
qa.plotting.plot_scalability(df, 0, "Y", "E3_after_oracle", "constant_1", 1024)
qa.plotting.plot_scalability(df, 0, "Z", "E3_after_oracle", "constant_1", 1024)

# balanced
qa.plotting.plot_scalability(df, 0, "X", "E3_after_oracle", "balanced", 1024)
qa.plotting.plot_scalability(df, 0, "Y", "E3_after_oracle", "balanced", 1024)
qa.plotting.plot_scalability(df, 0, "Z", "E3_after_oracle", "balanced", 1024)

# %%
# constant_0
qa.plotting.plot_scalability(df, 0, "X", "E4_after_final_H", "constant_0", 1024)
qa.plotting.plot_scalability(df, 0, "Y", "E4_after_final_H", "constant_0", 1024)
qa.plotting.plot_scalability(df, 0, "Z", "E4_after_final_H", "constant_0", 1024)

# constant_1
qa.plotting.plot_scalability(df, 0, "X", "E4_after_final_H", "constant_1", 1024)
qa.plotting.plot_scalability(df, 0, "Y", "E4_after_final_H", "constant_1", 1024)
qa.plotting.plot_scalability(df, 0, "Z", "E4_after_final_H", "constant_1", 1024)

# balanced
qa.plotting.plot_scalability(df, 0, "X", "E4_after_final_H", "balanced", 1024)
qa.plotting.plot_scalability(df, 0, "Y", "E4_after_final_H", "balanced", 1024)
qa.plotting.plot_scalability(df, 0, "Z", "E4_after_final_H", "balanced", 1024)

# %%
# constant_0
qa.plotting.plot_scalability(df, 90, "X", "E1_before_H", "constant_0", 1024)
qa.plotting.plot_scalability(df, 90, "Y", "E1_before_H", "constant_0", 1024)
qa.plotting.plot_scalability(df, 90, "Z", "E1_before_H", "constant_0", 1024)

# constant_1
qa.plotting.plot_scalability(df, 90, "X", "E1_before_H", "constant_1", 1024)
qa.plotting.plot_scalability(df, 90, "Y", "E1_before_H", "constant_1", 1024)
qa.plotting.plot_scalability(df, 90, "Z", "E1_before_H", "constant_1", 1024)

# balanced
qa.plotting.plot_scalability(df, 90, "X", "E1_before_H", "balanced", 1024)
qa.plotting.plot_scalability(df, 90, "Y", "E1_before_H", "balanced", 1024)
qa.plotting.plot_scalability(df, 90, "Z", "E1_before_H", "balanced", 1024)

# %%
# constant_0
qa.plotting.plot_scalability(df, 90, "X", "E3_after_oracle", "constant_0", 1024)
qa.plotting.plot_scalability(df, 90, "Y", "E3_after_oracle", "constant_0", 1024)
qa.plotting.plot_scalability(df, 90, "Z", "E3_after_oracle", "constant_0", 1024)

# constant_1
qa.plotting.plot_scalability(df, 90, "X", "E3_after_oracle", "constant_1", 1024)
qa.plotting.plot_scalability(df, 90, "Y", "E3_after_oracle", "constant_1", 1024)
qa.plotting.plot_scalability(df, 90, "Z", "E3_after_oracle", "constant_1", 1024)

# balanced
qa.plotting.plot_scalability(df, 90, "X", "E3_after_oracle", "balanced", 1024)
qa.plotting.plot_scalability(df, 90, "Y", "E3_after_oracle", "balanced", 1024)
qa.plotting.plot_scalability(df, 90, "Z", "E3_after_oracle", "balanced", 1024)

# %%
# constant_0
qa.plotting.plot_scalability(df, 90, "X", "E4_after_final_H", "constant_0", 1024)
qa.plotting.plot_scalability(df, 90, "Y", "E4_after_final_H", "constant_0", 1024)
qa.plotting.plot_scalability(df, 90, "Z", "E4_after_final_H", "constant_0", 1024)

# constant_1
qa.plotting.plot_scalability(df, 90, "X", "E4_after_final_H", "constant_1", 1024)
qa.plotting.plot_scalability(df, 90, "Y", "E4_after_final_H", "constant_1", 1024)
qa.plotting.plot_scalability(df, 90, "Z", "E4_after_final_H", "constant_1", 1024)

# balanced
qa.plotting.plot_scalability(df, 90, "X", "E4_after_final_H", "balanced", 1024)
qa.plotting.plot_scalability(df, 90, "Y", "E4_after_final_H", "balanced", 1024)
qa.plotting.plot_scalability(df, 90, "Z", "E4_after_final_H", "balanced", 1024)

# %%
# constant_0
qa.plotting.plot_scalability(df, 180, "X", "E1_before_H", "constant_0", 1024)
qa.plotting.plot_scalability(df, 180, "Y", "E1_before_H", "constant_0", 1024)
qa.plotting.plot_scalability(df, 180, "Z", "E1_before_H", "constant_0", 1024)

# constant_1
qa.plotting.plot_scalability(df, 180, "X", "E1_before_H", "constant_1", 1024)
qa.plotting.plot_scalability(df, 180, "Y", "E1_before_H", "constant_1", 1024)
qa.plotting.plot_scalability(df, 180, "Z", "E1_before_H", "constant_1", 1024)

# balanced
qa.plotting.plot_scalability(df, 180, "X", "E1_before_H", "balanced", 1024)
qa.plotting.plot_scalability(df, 180, "Y", "E1_before_H", "balanced", 1024)
qa.plotting.plot_scalability(df, 180, "Z", "E1_before_H", "balanced", 1024)

# %%
# constant_0
qa.plotting.plot_scalability(df, 180, "X", "E2_after_first_H", "constant_0", 1024)
qa.plotting.plot_scalability(df, 180, "Y", "E2_after_first_H", "constant_0", 1024)
qa.plotting.plot_scalability(df, 180, "Z", "E2_after_first_H", "constant_0", 1024)

# constant_1
qa.plotting.plot_scalability(df, 180, "X", "E2_after_first_H", "constant_1", 1024)
qa.plotting.plot_scalability(df, 180, "Y", "E2_after_first_H", "constant_1", 1024)
qa.plotting.plot_scalability(df, 180, "Z", "E2_after_first_H", "constant_1", 1024)

# balanced
qa.plotting.plot_scalability(df, 180, "X", "E2_after_first_H", "balanced", 1024)
qa.plotting.plot_scalability(df, 180, "Y", "E2_after_first_H", "balanced", 1024)
qa.plotting.plot_scalability(df, 180, "Z", "E2_after_first_H", "balanced", 1024)

# %%
# constant_0
qa.plotting.plot_scalability(df, 180, "X", "E3_after_oracle", "constant_0", 1024)
qa.plotting.plot_scalability(df, 180, "Y", "E3_after_oracle", "constant_0", 1024)
qa.plotting.plot_scalability(df, 180, "Z", "E3_after_oracle", "constant_0", 1024)

# constant_1
qa.plotting.plot_scalability(df, 180, "X", "E3_after_oracle", "constant_1", 1024)
qa.plotting.plot_scalability(df, 180, "Y", "E3_after_oracle", "constant_1", 1024)
qa.plotting.plot_scalability(df, 180, "Z", "E3_after_oracle", "constant_1", 1024)

# balanced
qa.plotting.plot_scalability(df, 180, "X", "E3_after_oracle", "balanced", 1024)
qa.plotting.plot_scalability(df, 180, "Y", "E3_after_oracle", "balanced", 1024)
qa.plotting.plot_scalability(df, 180, "Z", "E3_after_oracle", "balanced", 1024)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # balanced
# ----> 2 qa.plotting.plot_scalability(df, 180, "X", "E3_after_oracle", "balanced", 1024)
#       3 qa.plotting.plot_scalability(df, 180, "Y", "E3_after_oracle", "balanced", 1024)
#       4 qa.plotting.plot_scalability(df, 180, "Z", "E3_after_oracle", "balanced", 1024)
#
# NameError: name 'qa' is not defined

# %%
z
